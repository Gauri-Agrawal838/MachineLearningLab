# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri-Agrawal838/MachineLearningLab/blob/main/17_04_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = '/content/brain-stroke.csv'

import pandas as pd
df = pd.read_csv(url)
df.shape
# Out:
# (5110, 12)

# %%
df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail(5)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df['gender'].replace('Female',0, inplace=True )
df['gender'].replace('Male',1, inplace=True )
df['gender'].replace('Others',2, inplace=True )

# %%
df.head(5)
# Out:
#       id gender   age  hypertension  heart_disease ever_married  \
# 0   9046      1  67.0             0              1          Yes
# 1  51676      0  61.0             0              0          Yes
# 2  31112      1  80.0             0              1          Yes
# 3  60182      0  49.0             0              0          Yes
# 4   1665      0  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['gender'].unique()
# Out:
# array([1, 0, 'Other'], dtype=object)

# %%
df['work_type'].replace('Private',10,inplace=True)
df['work_type'].replace('Self-employed',20,inplace=True)
df['work_type'].replace('Govt_job',30,inplace=True)

# %%
df['Residence_type'].replace('Urban',100,inplace=True)
df['Residence_type'].replace('Rural',200,inplace=True)

# %%
df['Residence_type'].unique()
# Out:
# array([100, 200])

# %%
df['smoking_status'].replace('formerly smoked',1000,inplace=True)
df['smoking_status'].replace('smokes',2000,inplace=True)
df['smoking_status'].replace('never smoked',3000,inplace=True)
df['smoking_status'].replace('Unknown',4000,inplace=True)

# %%
df['ever_married'].replace('Yes',10000,inplace=True)
df['ever_married'].replace('No',20000,inplace=True)

# %%
df
# Out:
#          id gender   age  hypertension  heart_disease  ever_married work_type  \
# 0      9046      1  67.0             0              1         10000        10
# 1     51676      0  61.0             0              0         10000        20
# 2     31112      1  80.0             0              1         10000        10
# 3     60182      0  49.0             0              0         10000        10
# 4      1665      0  79.0             1              0         10000        20
# ...     ...    ...   ...           ...            ...           ...       ...
# 5105  18234      0  80.0             1              0         10000        10
# 5106  44873      0  81.0             0              0         10000        20
# 5107  19723      0  35.0             0              0         10000        20
# 5108  37544      1  51.0             0              0         10000        10
# 5109  44679      0  44.0             0              0         10000        30
#
# ...

# %% [markdown]
# There are 3 ways to handle NaN
# 1. Deleting the rows which contain NaN
# 2. Replace it by Zero
# 3. Apply Imputation like KNN imputation

# %% [markdown]
# Methods
# 1. Replace it by Zero

# %%
df1=df.replace(to_replace = np.NaN, value =0)

# %%
df1
# Out:
#          id gender   age  hypertension  heart_disease  ever_married work_type  \
# 0      9046      1  67.0             0              1         10000        10
# 1     51676      0  61.0             0              0         10000        20
# 2     31112      1  80.0             0              1         10000        10
# 3     60182      0  49.0             0              0         10000        10
# 4      1665      0  79.0             1              0         10000        20
# ...     ...    ...   ...           ...            ...           ...       ...
# 5105  18234      0  80.0             1              0         10000        10
# 5106  44873      0  81.0             0              0         10000        20
# 5107  19723      0  35.0             0              0         10000        20
# 5108  37544      1  51.0             0              0         10000        10
# 5109  44679      0  44.0             0              0         10000        30
#
# ...

# %% [markdown]
# 2. Deleting Rows

# %%
df2.dropna()
# Out:
#          id gender   age  hypertension  heart_disease  ever_married work_type  \
# 0      9046      1  67.0             0              1         10000        10
# 2     31112      1  80.0             0              1         10000        10
# 3     60182      0  49.0             0              0         10000        10
# 4      1665      0  79.0             1              0         10000        20
# 5     56669      1  81.0             0              0         10000        10
# ...     ...    ...   ...           ...            ...           ...       ...
# 5104  14180      0  13.0             0              0         20000  children
# 5106  44873      0  81.0             0              0         10000        20
# 5107  19723      0  35.0             0              0         10000        20
# 5108  37544      1  51.0             0              0         10000        10
# 5109  44679      0  44.0             0              0         10000        30
#
# ...

# %% [markdown]
# 3. Using Imputation

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/brain-stroke.csv')
df2 = df
df3 = df

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['gender']= label_encoder.fit_transform(df['gender'])
df['ever_married']= label_encoder.fit_transform(df['ever_married'])
df['work_type']= label_encoder.fit_transform(df['work_type'])
df['Residence_type']= label_encoder.fit_transform(df['Residence_type'])
df['smoking_status']= label_encoder.fit_transform(df['smoking_status'])
df
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046       1  67.0             0              1             1
# 1     51676       0  61.0             0              0             1
# 2     31112       1  80.0             0              1             1
# 3     60182       0  49.0             0              0             1
# 4      1665       0  79.0             1              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234       0  80.0             1              0             1
# 5106  44873       0  81.0             0              0             1
# 5107  19723       0  35.0             0              0             1
# 5108  37544       1  51.0             0              0             1
# 5109  44679       0  44.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# ...

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer()
imputed_data = imputer.fit_transform(df)
df_temp = pd.DataFrame(imputed_data)
df_temp.columns = df.columns
df['bmi'] = df_temp['bmi']

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046       1  67.0             0              1             1
# 1     51676       0  61.0             0              0             1
# 2     31112       1  80.0             0              1             1
# 3     60182       0  49.0             0              0             1
# 4      1665       0  79.0             1              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234       0  80.0             1              0             1
# 5106  44873       0  81.0             0              0             1
# 5107  19723       0  35.0             0              0             1
# 5108  37544       1  51.0             0              0             1
# 5109  44679       0  44.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...
